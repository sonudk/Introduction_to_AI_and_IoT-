# %% [markdown]
# <a href="https://colab.research.google.com/github/sonudk/Introduction_to_AI_and_IoT-/blob/master/basic_plotting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.random.random(10)
y = np.random.random(10)
plt.plot(x,y,'b')
plt.plot(x,y,'o')

# %%
import pandas as pd
data = pd.read_excel('Book1.xlsx')

# %%
data.plot(kind = 'line')

# %%
data['lust'].plot(kind = 'hist')
